# %%
import json
import pandas as pd
import geopandas as gpd
import numpy as np
from sqlalchemy import create_engine

# %% [markdown]
# # Change in working age population 1999 - 2019

# %% [markdown]
# — Change in working age population (20-64 years) 1999-2019 (Lorraine: 1999-2017)
#
# — Territorial entities: districts (Wallonia), employment areas (Lorraine), Grand Duchy (Luxembourg), Kreise (Saarland, Rheinland-Pfalz)
#
# — Statistical data sources: Destatis, INSEE, Statbel, STATEC. Calculations: OIE/IBA 2020
#
# — Geodata sources: Act Luxembourg 2017, IGN France 2017, GeoBasis-DE/BKG 2017, NGI-Belgium 2017. Harmonisation: SIG-GR/GIS-GR 2020

# %%
workchange = gpd.read_file('/Users/szabonikolett/Downloads/change-in-working-age-population-1999-2019-2022-evo-pop-20-64years-1999-2019-0.geojson')

# %%
workchange
# Out:
#     OBJECTID              name region               de_entity       fr_entity  \
# 0          1          Nivelles    WAL  Kreis (arrondissement)  Arrondissement
# 1          2              Mons    WAL  Kreis (arrondissement)  Arrondissement
# 2          3               Huy    WAL  Kreis (arrondissement)  Arrondissement
# 3          4             Liège    WAL  Kreis (arrondissement)  Arrondissement
# 4          5           Waremme    WAL  Kreis (arrondissement)  Arrondissement
# ..       ...               ...    ...                     ...             ...
# 74        75          Soignies    WAL  Kreis (arrondissement)  Arrondissement
# 75        76             Thuin    WAL  Kreis (arrondissement)  Arrondissement
# 76        77  Tournai-Mouscron    WAL  Kreis (arrondissement)  Arrondissement
# 77        78       La Louvière    WAL  Kreis (arrondissement)  Arrondissement
# 78        79        Luxembourg    LUX           Großherzogtum     Grand-Duché
#
#                     en_entity  Pop_20_64_1999  Pop_20_64_2019  \
# 0   District (arrondissement)          205678          233225
# 1   District (arrondissement)          146238          152166
# 2   District (arrondissement)           57971           66806
# 3   District (arrondissement)          346789          365136
# 4   District (arrondissement)           39772           47761
# ..                        ...             ...             ...
# 74  District (arrondissement)           54719           61045
# 75  District (arrondissement)           51206           52984
# 76  District (arrondissement)          122277          128896
# 77  District (arrondissement)           79095           82335
# 78                Grand Duchy          262293          393753
#
#    Evo_20_64_1999_2019_txt reference_period description  \
# 0                   +13,4%        1999-2019
# 1                    +4,1%        1999-2019
# 2                   +15,2%        1999-2019
# 3                    +5,3%        1999-2019
# 4                   +20,1%        1999-2019
# ..                     ...              ...         ...
# 74                  +11,6%        1999-2019
# 75                   +3,5%        1999-2019
# 76                   +5,4%        1999-2019
# 77                   +4,1%        1999-2019
# 78                  +50,1%        1999-2019
#
#                                              geometry
# 0   POLYGON ((4.75090 50.80705, 4.74888 50.80724, ...
# 1   POLYGON ((3.91197 50.61542, 3.91230 50.61647, ...
# 2   POLYGON ((5.29186 50.63330, 5.28140 50.63716, ...
# 3   POLYGON ((5.69315 50.81199, 5.69263 50.81205, ...
# 4   MULTIPOLYGON (((5.34921 50.63342, 5.34873 50.6...
# ..                                                ...
# 74  POLYGON ((4.09185 50.66885, 4.08809 50.66575, ...
# 75  POLYGON ((4.29384 50.42438, 4.29343 50.42548, ...
# 76  MULTIPOLYGON (((3.45931 50.76215, 3.45996 50.7...
# 77  POLYGON ((4.20365 50.51621, 4.18635 50.52517, ...
# 78  POLYGON ((6.02490 50.18278, 6.02474 50.18274, ...
#
# [79 rows x 12 columns]

# %%
def clean_data(df):
    df.columns = [str.lower(col).replace(' ', '_') for col in df.columns]
    return df

# %%
clean_data(workchange).head()
# Out:
#    objectid      name region               de_entity       fr_entity  \
# 0         1  Nivelles    WAL  Kreis (arrondissement)  Arrondissement
# 1         2      Mons    WAL  Kreis (arrondissement)  Arrondissement
# 2         3       Huy    WAL  Kreis (arrondissement)  Arrondissement
# 3         4     Liège    WAL  Kreis (arrondissement)  Arrondissement
# 4         5   Waremme    WAL  Kreis (arrondissement)  Arrondissement
#
#                    en_entity  pop_20_64_1999  pop_20_64_2019  \
# 0  District (arrondissement)          205678          233225
# 1  District (arrondissement)          146238          152166
# 2  District (arrondissement)           57971           66806
# 3  District (arrondissement)          346789          365136
# 4  District (arrondissement)           39772           47761
#
#   evo_20_64_1999_2019_txt reference_period description  \
# 0                  +13,4%        1999-2019
# 1                   +4,1%        1999-2019
# 2                  +15,2%        1999-2019
# 3                   +5,3%        1999-2019
# 4                  +20,1%        1999-2019
#
#                                             geometry
# 0  POLYGON ((4.75090 50.80705, 4.74888 50.80724, ...
# 1  POLYGON ((3.91197 50.61542, 3.91230 50.61647, ...
# 2  POLYGON ((5.29186 50.63330, 5.28140 50.63716, ...
# 3  POLYGON ((5.69315 50.81199, 5.69263 50.81205, ...
# 4  MULTIPOLYGON (((5.34921 50.63342, 5.34873 50.6...

# %%
# renaming columns
workchange.rename(columns={'name': 'city' , 'pop_20_64_1999': 'population_1999', 'pop_20_64_2019': 'population_2019', 'evo_20_64_1999_2019_txt': 'change_in_percentage'}, inplace=True)

# %%
workchange['city'].value_counts()
# Out:
# Neufchâteau                2
# Nivelles                   1
# Merzig-Wadern              1
# Nancy                      1
# Lunéville                  1
#                           ..
# Eifelkreis Bitburg-Prüm    1
# Bernkastel-Wittlich        1
# Trier                      1
# Westerwaldkreis            1
# Luxembourg                 1
# Name: city, Length: 78, dtype: int64

# %%
# checking the one city listed twice. Not a duplicate, can't be dropped, details differ so keeping both
workchange.loc[workchange['city'] == 'Neufchâteau']
# Out:
#     objectid         city region                           de_entity  \
# 8          9  Neufchâteau    WAL              Kreis (arrondissement)
# 69        70  Neufchâteau    LOR  Arbeitsmarktregion (zone d'emploi)
#
#          fr_entity                        en_entity  population_1999  \
# 8   Arrondissement        District (arrondissement)            31076
# 69   Zone d'emploi  Employment area (zone d'emploi)            31245
#
#     population_2019 change_in_percentage reference_period description  \
# 8             36428               +17,2%        1999-2019
# 69            26703               -14,5%        1999-2017
#
#                                              geometry
# 8   POLYGON ((5.06469 50.10367, 5.06135 50.10537, ...
# 69  POLYGON ((5.74610 48.47625, 5.74243 48.47450, ...

# %%
workchange.isna().sum() # no NaN values to deal with
# Out:
# objectid                0
# city                    0
# region                  0
# de_entity               0
# fr_entity               0
# en_entity               0
# population_1999         0
# population_2019         0
# change_in_percentage    0
# reference_period        0
# description             0
# geometry                0
# dtype: int64

# %%
#workchange.to_csv('/Users/szabonikolett/Downloads/workchange.csv')

# %% [markdown]
# Following columns will be dropped:
# - desription (it has no values)
# - reg_preiod (the whole df is about a fix time frame, hence pointless to keep)
# - goemetry (might be good in Tableau, but for analysis it seves no useful info)

# %%
# general cleaning:  removing % + , ; dropping redundant columns 
workchange['change_in_percentage'] = workchange['change_in_percentage'].str.replace('%', '')
workchange['change_in_percentage'] = workchange['change_in_percentage'].str.replace(',', '.')
workchange['change_in_percentage'] = workchange['change_in_percentage'].str.replace('+', '')

workchange = workchange.drop(['objectid', 'de_entity', 'fr_entity', 'en_entity', 'description', 'reference_period' ,'geometry'], axis=1)
workchange
# Out:
# /var/folders/0j/8qpr4dtj39x29g5tw9dvh26m0000gn/T/ipykernel_15760/2364153430.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   workchange['change_in_percentage'] = workchange['change_in_percentage'].str.replace('+', '')
#                 city region  population_1999  population_2019  \
# 0           Nivelles    WAL           205678           233225
# 1               Mons    WAL           146238           152166
# 2                Huy    WAL            57971            66806
# 3              Liège    WAL           346789           365136
# 4            Waremme    WAL            39772            47761
# ..               ...    ...              ...              ...
# 74          Soignies    WAL            54719            61045
# 75             Thuin    WAL            51206            52984
# 76  Tournai-Mouscron    WAL           122277           128896
# 77       La Louvière    WAL            79095            82335
# 78        Luxembourg    LUX           262293           393753
#
#    change_in_percentage
# 0                  13.4
# 1                   4.1
# 2                  15.2
# 3                   5.3
# 4                  20.1
# ..                  ...
# 74                 11.6
# 75                  3.5
# 76                  5.4
# 77                  4.1
# 78                 50.1
#
# [79 rows x 5 columns]

# %%
workchange.dtypes
# Out:
# city                    object
# region                  object
# population_1999          int64
# population_2019          int64
# change_in_percentage    object
# dtype: object

# %%
#workchange['change_in_percentage'] = workchange['change_in_precentage].astype(float)

# %%
workchange['population_2019'].mean()
# Out:
# 87202.58227848102

# %%
# later on I used a merged dataset so this is not the one 

#connection_string = 'mysql+pymysql://root:' + password + '@localhost/mid_project'
#engine = create_engine(connection_string) # creates the connection to the database

#workchange.to_sql('workchange', con=engine, index=False)

# %% [markdown]
# # Projection of working age poupulation 2020-2050

# %% [markdown]
# — Projection of working age population (20-64 years) 2020-2050
#
# — Territorial entities: districts (Wallonia), departments (Lorraine), Grand Duchy (Luxembourg), Kreise (Saarland, Rheinland-Pfalz)
#
# — Statistical data sources: INSEE, Statec, Statbel-DEMOBEL, Statistisches Landesamt Rheinland-Pfalz, Statistisches Amt Saarland/Destatis.Calculations: OIE/IBA 2020 — Geodata sources: Act Luxembourg 2017, IGN France 2017, GeoBasis-DE/BKG 2017, NGI-Belgium 2017.Harmonisation: SIG-GR/GIS-GR 2020
#
# — Territorial entities: districts (Wallonia), departments (Lorraine), Grand Duchy (Luxembourg), Kreise (Saarland, Rheinland-Pfalz)
#
# — Statistical data sources: INSEE, Statec, Statbel-DEMOBEL, Statistisches Landesamt Rheinland-Pfalz, Statistisches Amt Saarland/Destatis. Calculations: OIE/IBA 2020
#
# — Geodata sources: Act Luxembourg 2017, IGN France 2017, GeoBasis-DE/BKG 2017, NGI-Belgium 2017. Harmonisation: SIG-GR/GIS-GR 2020

# %%
projection = gpd.read_file('/Users/szabonikolett/Downloads/projection-of-working-age-population-2020-2050-2024-projection-2020-2050-0.geojson')

# %%
clean_data(projection)
# Out:
#     objectid region                              name  \
# 0          1    SAR                          Saarland
# 1          2    WAL                          Nivelles
# 2          3    WAL                               Ath
# 3          4    WAL                         Charleroi
# 4          5    WAL                              Mons
# ..       ...    ...                               ...
# 58        59    RLP                      Mainz-Bingen
# 59        60    RLP                      Südwestpfalz
# 60        61    WAL                        DG Belgien
# 61        62    WAL  Verviers - communes francophones
# 62        63    LUX                        Luxembourg
#
#                                             de_entity  \
# 0                                          Bundesland
# 1                              Kreis (arrondissement)
# 2                              Kreis (arrondissement)
# 3                              Kreis (arrondissement)
# 4                              Kreis (arrondissement)
# ..                                                ...
# 58                                          Landkreis
# 59                                          Landkreis
# 60  Verviers - Gemeinden Deutschsprachige Gemeinsc...
# 61  Verviers - Gemeinden franz.sprachige Gemeinschaft
# 62                                      Großherzogtum
#
#                                             fr_entity  \
# 0                                                Land
# 1                                      Arrondissement
# 2                                      Arrondissement
# 3                                      Arrondissement
# 4                                      Arrondissement
# ..                                                ...
# 58                         Arrondissement (Landkreis)
# 59                         Arrondissement (Landkreis)
# 60  Verviers - communes de la Communauté germanophone
# 61     Verviers - communes de la Communauté française
# 62                                        Grand-Duché
#
#                                             en_entity  pop_20_64_2020  \
# 0                                       Federal state          585000
# 1                           District (arrondissement)          234103
# 2                           District (arrondissement)           51539
# 3                           District (arrondissement)          249171
# 4                           District (arrondissement)          151870
# ..                                                ...             ...
# 58                               District (Landkreis)          126775
# 59                               District (Landkreis)           55345
# 60  Verviers - municipalities of the German community           45838
# 61  Verviers - municipalities of the French Community          121232
# 62                                        Grand Duchy          400597
#
#     pop_20_64_2050 evo_pop_20_64_2020_2050_txt description  \
# 0           451000                      -22,9%
# 1           245259                       +4,8%
# 2            55221                       +7,1%
# 3           227580                       -8,7%
# 4           145531                       -4,2%
# ..             ...                         ...         ...
# 58          108510                      -14,4%
# 59           40524                      -26,8%
# 60           41196                      -10,1%
# 61          116945                       -3,5%
# 62          531808                      +32,8%
#
#                                              geometry
# 0   POLYGON ((7.06429 49.62671, 7.06285 49.62778, ...
# 1   POLYGON ((4.75090 50.80705, 4.74888 50.80724, ...
# 2   POLYGON ((3.70908 50.77467, 3.70946 50.77585, ...
# 3   POLYGON ((4.24081 50.60027, 4.24102 50.60162, ...
# 4   POLYGON ((3.91197 50.61542, 3.91230 50.61647, ...
# ..                                                ...
# 58  POLYGON ((7.76660 50.08136, 7.76484 50.08259, ...
# 59  POLYGON ((7.60906 49.37297, 7.60780 49.37432, ...
# 60  MULTIPOLYGON (((6.20656 50.52085, 6.20629 50.5...
# 61  POLYGON ((5.96840 50.76080, 5.96175 50.76194, ...
# 62  POLYGON ((6.02490 50.18278, 6.02474 50.18274, ...
#
# [63 rows x 11 columns]

# %%
projection['description'].value_counts() # empty column
# Out:
#     63
# Name: description, dtype: int64

# %%
projection['description'].nunique()
# Out:
# 1

# %%
# unifying the columns in both dataframes 
# removing % + , ; renaming columns, dropping redundant columns 

projection.rename(columns={'name': 'city', 'pop_20_64_2020': 'population_2020', 'pop_20_64_2050': 'population_2050' , 'evo_pop_20_64_2020_2050_txt': 'pop_projection_percentage'}, inplace=True)

projection['pop_projection_percentage'] = projection['pop_projection_percentage'].str.replace('%', '')                                               
projection['pop_projection_percentage'] = projection['pop_projection_percentage'].str.replace('+', '')
projection['pop_projection_percentage'] = projection['pop_projection_percentage'].str.replace(',', '.') 

#projection = projection.drop(['objectid', 'de_entity', 'fr_entity', 'en_entity', 'description', 'geometry'], axis=1)
projection
# Out:
# /var/folders/0j/8qpr4dtj39x29g5tw9dvh26m0000gn/T/ipykernel_15760/4203001153.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   projection['pop_projection_percentage'] = projection['pop_projection_percentage'].str.replace('+', '')
#     objectid region                              city  \
# 0          1    SAR                          Saarland
# 1          2    WAL                          Nivelles
# 2          3    WAL                               Ath
# 3          4    WAL                         Charleroi
# 4          5    WAL                              Mons
# ..       ...    ...                               ...
# 58        59    RLP                      Mainz-Bingen
# 59        60    RLP                      Südwestpfalz
# 60        61    WAL                        DG Belgien
# 61        62    WAL  Verviers - communes francophones
# 62        63    LUX                        Luxembourg
#
#                                             de_entity  \
# 0                                          Bundesland
# 1                              Kreis (arrondissement)
# 2                              Kreis (arrondissement)
# 3                              Kreis (arrondissement)
# 4                              Kreis (arrondissement)
# ..                                                ...
# 58                                          Landkreis
# 59                                          Landkreis
# 60  Verviers - Gemeinden Deutschsprachige Gemeinsc...
# 61  Verviers - Gemeinden franz.sprachige Gemeinschaft
# 62                                      Großherzogtum
#
#                                             fr_entity  \
# 0                                                Land
# 1                                      Arrondissement
# 2                                      Arrondissement
# 3                                      Arrondissement
# 4                                      Arrondissement
# ..                                                ...
# 58                         Arrondissement (Landkreis)
# 59                         Arrondissement (Landkreis)
# 60  Verviers - communes de la Communauté germanophone
# 61     Verviers - communes de la Communauté française
# 62                                        Grand-Duché
#
#                                             en_entity  population_2020  \
# 0                                       Federal state           585000
# 1                           District (arrondissement)           234103
# 2                           District (arrondissement)            51539
# 3                           District (arrondissement)           249171
# 4                           District (arrondissement)           151870
# ..                                                ...              ...
# 58                               District (Landkreis)           126775
# 59                               District (Landkreis)            55345
# 60  Verviers - municipalities of the German community            45838
# 61  Verviers - municipalities of the French Community           121232
# 62                                        Grand Duchy           400597
#
#     population_2050 pop_projection_percentage description  \
# 0            451000                     -22.9
# 1            245259                       4.8
# 2             55221                       7.1
# 3            227580                      -8.7
# 4            145531                      -4.2
# ..              ...                       ...         ...
# 58           108510                     -14.4
# 59            40524                     -26.8
# 60            41196                     -10.1
# 61           116945                      -3.5
# 62           531808                      32.8
#
#                                              geometry
# 0   POLYGON ((7.06429 49.62671, 7.06285 49.62778, ...
# 1   POLYGON ((4.75090 50.80705, 4.74888 50.80724, ...
# 2   POLYGON ((3.70908 50.77467, 3.70946 50.77585, ...
# 3   POLYGON ((4.24081 50.60027, 4.24102 50.60162, ...
# 4   POLYGON ((3.91197 50.61542, 3.91230 50.61647, ...
# ..                                                ...
# 58  POLYGON ((7.76660 50.08136, 7.76484 50.08259, ...
# 59  POLYGON ((7.60906 49.37297, 7.60780 49.37432, ...
# 60  MULTIPOLYGON (((6.20656 50.52085, 6.20629 50.5...
# 61  POLYGON ((5.96840 50.76080, 5.96175 50.76194, ...
# 62  POLYGON ((6.02490 50.18278, 6.02474 50.18274, ...
#
# [63 rows x 11 columns]

# %%
projection['city'].value_counts()
# Out:
# Saarland                     1
# Worms                        1
# Westerwaldkreis              1
# Trier                        1
# Bernkastel-Wittlich          1
#                             ..
# Altenkirchen (Westerwald)    1
# Bad Kreuznach                1
# Birkenfeld                   1
# Cochem-Zell                  1
# Luxembourg                   1
# Name: city, Length: 63, dtype: int64

# %%
projection.dtypes
# Out:
# objectid                        int64
# region                         object
# city                           object
# de_entity                      object
# fr_entity                      object
# en_entity                      object
# population_2020                 int64
# population_2050                 int64
# pop_projection_percentage      object
# description                    object
# geometry                     geometry
# dtype: object

# %%
projection['pop_projection_percentage'] = projection['pop_projection_percentage'].astype(float)

# %%
projection.dtypes
# Out:
# objectid                        int64
# region                         object
# city                           object
# de_entity                      object
# fr_entity                      object
# en_entity                      object
# population_2020                 int64
# population_2050                 int64
# pop_projection_percentage     float64
# description                    object
# geometry                     geometry
# dtype: object

# %%
projection.isna().sum() # no NaN values to deal with
# Out:
# objectid                     0
# region                       0
# city                         0
# de_entity                    0
# fr_entity                    0
# en_entity                    0
# population_2020              0
# population_2050              0
# pop_projection_percentage    0
# description                  0
# geometry                     0
# dtype: int64

# %%
projection['population_2020'].mean()
# Out:
# 108656.11111111111

# %%
projection['city'].value_counts()
# Out:
# Saarland                     1
# Worms                        1
# Westerwaldkreis              1
# Trier                        1
# Bernkastel-Wittlich          1
#                             ..
# Altenkirchen (Westerwald)    1
# Bad Kreuznach                1
# Birkenfeld                   1
# Cochem-Zell                  1
# Luxembourg                   1
# Name: city, Length: 63, dtype: int64

# %%
workchange['city'].value_counts()
# Out:
# Neufchâteau                2
# Nivelles                   1
# Merzig-Wadern              1
# Nancy                      1
# Lunéville                  1
#                           ..
# Eifelkreis Bitburg-Prüm    1
# Bernkastel-Wittlich        1
# Trier                      1
# Westerwaldkreis            1
# Luxembourg                 1
# Name: city, Length: 78, dtype: int64

# %%
workchange['city'].isin(projection['city']).value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 74     True
# 75     True
# 76    False
# 77    False
# 78     True
# Name: city, Length: 79, dtype: bool>

# %%
#newdf = pd.concat([workchange, projection], axis=1)
#newdf.head(60)

# %%
#newdf.isna().sum()

# %%
#df.to_csv('data.csv').
#/Users/szabonikolett/Downloads

#projection.to_csv('/Users/szabonikolett/Downloads/projection.csv')

# %% [markdown]
# ## Final dataset

# %%
# merging them to use it for visualisation
mergeddata = pd.merge(workchange, projection, on=['city'], how='inner')
mergeddata
# Out:
#                                 city region_x  population_1999  \
# 0                           Nivelles      WAL           205678
# 1                               Mons      WAL           146238
# 2                                Huy      WAL            57971
# 3                              Liège      WAL           346789
# 4                            Waremme      WAL            39772
# 5                              Arlon      WAL            30562
# 6                           Bastogne      WAL            22666
# 7                  Marche-en-Famenne      WAL            28197
# 8                        Neufchâteau      WAL            31076
# 9                        Neufchâteau      LOR            31245
# 10                            Virton      WAL            26930
# 11                            Dinant      WAL            56459
# 12                             Namur      WAL           164849
# 13                     Philippeville      WAL            35739
# 14                           Koblenz      RLP            67912
# 15                         Ahrweiler      RLP            77226
# 16         Altenkirchen (Westerwald)      RLP            81640
# 17                     Bad Kreuznach      RLP            95113
# 18                        Birkenfeld      RLP            53944
# 19                       Cochem-Zell      RLP            38668
# 20                     Mayen-Koblenz      RLP           128291
# 21                           Neuwied      RLP           110159
# 22              Rhein-Hunsrück-Kreis      RLP            62281
# 23                  Rhein-Lahn-Kreis      RLP            77484
# 24                   Westerwaldkreis      RLP           120778
# 25                             Trier      RLP            63414
# 26               Bernkastel-Wittlich      RLP            67695
# 27           Eifelkreis Bitburg-Prüm      RLP            56325
# 28                       Vulkaneifel      RLP            37133
# 29                    Trier-Saarburg      RLP            83216
# 30               Frankenthal (Pfalz)      RLP            30248
# 31                 KS Kaiserslautern      RLP            63821
# 32             Ludwigshafen am Rhein      RLP           104163
# 33                             Mainz      RLP           123834
# 34                         Pirmasens      RLP            27662
# 35                            Speyer      RLP            30999
# 36                             Worms      RLP            49932
# 37                       Zweibrücken      RLP            21520
# 38                       Alzey-Worms      RLP            74884
# 39                      Bad Dürkheim      RLP            82065
# 40                  Donnersbergkreis      RLP            47055
# 41                       Germersheim      RLP            77473
# 42                 LK Kaiserslautern      RLP            66106
# 43                             Kusel      RLP            47380
# 44               Landau in der Pfalz      RLP            25362
# 45               Südliche Weinstraße      RLP            66157
# 46                 Rhein-Pfalz-Kreis      RLP            91923
# 47                      Mainz-Bingen      RLP           122329
# 48                      Südwestpfalz      RLP            64476
# 49                        DG Belgien      WAL            42091
# 50  Verviers - communes francophones      WAL           111266
# 51                               Ath      WAL            66654
# 52                         Charleroi      WAL           229147
# 53                          Soignies      WAL            54719
# 54                             Thuin      WAL            51206
# 55                        Luxembourg      LUX           262293
#
#     population_2019 change_in_percentage  objectid region_y  \
# 0            233225                 13.4         2      WAL
# 1            152166                  4.1         5      WAL
# 2             66806                 15.2        10      WAL
# 3            365136                  5.3        11      WAL
# 4             47761                 20.1        12      WAL
# 5             37753                 23.5        13      WAL
# 6             28505                 25.8        14      WAL
# 7             33226                 17.8        15      WAL
# 8             36428                 17.2        16      WAL
# 9             26703                -14.5        16      WAL
# 10            31051                 15.3        17      WAL
# 11            64373                 14.0        18      WAL
# 12           186591                 13.2        19      WAL
# 13            38709                  8.3        20      WAL
# 14            70303                  3.5        25      RLP
# 15            75285                 -2.5        26      RLP
# 16            76147                 -6.7        27      RLP
# 17            92323                 -2.9        28      RLP
# 18            47074                -12.7        29      RLP
# 19            35987                 -6.9        30      RLP
# 20           127753                 -0.4        31      RLP
# 21           106702                 -3.1        32      RLP
# 22            60719                 -2.5        33      RLP
# 23            71774                 -7.4        34      RLP
# 24           120789                  0.0        35      RLP
# 25            72625                 14.5        36      RLP
# 26            66276                 -2.1        37      RLP
# 27            59455                  5.6        38      RLP
# 28            35420                 -4.6        39      RLP
# 29            89822                  7.9        40      RLP
# 30            28282                 -6.5        41      RLP
# 31            62763                 -1.7        42      RLP
# 32           104125                  0.0        43      RLP
# 33           142671                 15.2        44      RLP
# 34            23149                -16.3        46      RLP
# 35            29803                 -3.9        47      RLP
# 36            50049                  0.2        48      RLP
# 37            20249                 -5.9        49      RLP
# 38            78324                  4.6        50      RLP
# 39            77407                 -5.7        51      RLP
# 40            44616                 -5.2        52      RLP
# 41            78916                  1.9        53      RLP
# 42            62455                 -5.5        54      RLP
# 43            41468                -12.5        55      RLP
# 44            29681                 17.0        56      RLP
# 45            65096                 -1.6        57      RLP
# 46            90552                 -1.5        58      RLP
# 47           126207                  3.2        59      RLP
# 48            55915                -13.3        60      RLP
# 49            45876                  9.0        61      WAL
# 50           121367                  9.1        62      WAL
# 51            75020                 12.6         3      WAL
# 52           229892                  0.3         4      WAL
# 53            61045                 11.6         7      WAL
# 54            52984                  3.5         8      WAL
# 55           393753                 50.1        63      LUX
#
#                                             de_entity  \
# 0                              Kreis (arrondissement)
# 1                              Kreis (arrondissement)
# 2                              Kreis (arrondissement)
# 3                              Kreis (arrondissement)
# 4                              Kreis (arrondissement)
# 5                              Kreis (arrondissement)
# 6                              Kreis (arrondissement)
# 7                              Kreis (arrondissement)
# 8                              Kreis (arrondissement)
# 9                              Kreis (arrondissement)
# 10                             Kreis (arrondissement)
# 11                             Kreis (arrondissement)
# 12                             Kreis (arrondissement)
# 13                             Kreis (arrondissement)
# 14                                   kreisfreie Stadt
# 15                                          Landkreis
# 16                                          Landkreis
# 17                                          Landkreis
# 18                                          Landkreis
# 19                                          Landkreis
# 20                                          Landkreis
# 21                                          Landkreis
# 22                                          Landkreis
# 23                                          Landkreis
# 24                                          Landkreis
# 25                                   kreisfreie Stadt
# 26                                          Landkreis
# 27                                          Landkreis
# 28                                          Landkreis
# 29                                          Landkreis
# 30                                   kreisfreie Stadt
# 31                                   kreisfreie Stadt
# 32                                   kreisfreie Stadt
# 33                                   kreisfreie Stadt
# 34                                   kreisfreie Stadt
# 35                                   kreisfreie Stadt
# 36                                   kreisfreie Stadt
# 37                                   kreisfreie Stadt
# 38                                          Landkreis
# 39                                          Landkreis
# 40                                          Landkreis
# 41                                          Landkreis
# 42                                          Landkreis
# 43                                          Landkreis
# 44                                   kreisfreie Stadt
# 45                                          Landkreis
# 46                                          Landkreis
# 47                                          Landkreis
# 48                                          Landkreis
# 49  Verviers - Gemeinden Deutschsprachige Gemeinsc...
# 50  Verviers - Gemeinden franz.sprachige Gemeinschaft
# 51                             Kreis (arrondissement)
# 52                             Kreis (arrondissement)
# 53                             Kreis (arrondissement)
# 54                             Kreis (arrondissement)
# 55                                      Großherzogtum
#
#                                             fr_entity  \
# 0                                      Arrondissement
# 1                                      Arrondissement
# 2                                      Arrondissement
# 3                                      Arrondissement
# 4                                      Arrondissement
# 5                                      Arrondissement
# 6                                      Arrondissement
# 7                                      Arrondissement
# 8                                      Arrondissement
# 9                                      Arrondissement
# 10                                     Arrondissement
# 11                                     Arrondissement
# 12                                     Arrondissement
# 13                                     Arrondissement
# 14       Ville hors arrondissement (kreisfreie Stadt)
# 15                         Arrondissement (Landkreis)
# 16                         Arrondissement (Landkreis)
# 17                         Arrondissement (Landkreis)
# 18                         Arrondissement (Landkreis)
# 19                         Arrondissement (Landkreis)
# 20                         Arrondissement (Landkreis)
# 21                         Arrondissement (Landkreis)
# 22                         Arrondissement (Landkreis)
# 23                         Arrondissement (Landkreis)
# 24                         Arrondissement (Landkreis)
# 25       Ville hors arrondissement (kreisfreie Stadt)
# 26                         Arrondissement (Landkreis)
# 27                         Arrondissement (Landkreis)
# 28                         Arrondissement (Landkreis)
# 29                         Arrondissement (Landkreis)
# 30       Ville hors arrondissement (kreisfreie Stadt)
# 31       Ville hors arrondissement (kreisfreie Stadt)
# 32       Ville hors arrondissement (kreisfreie Stadt)
# 33       Ville hors arrondissement (kreisfreie Stadt)
# 34       Ville hors arrondissement (kreisfreie Stadt)
# 35       Ville hors arrondissement (kreisfreie Stadt)
# 36       Ville hors arrondissement (kreisfreie Stadt)
# 37       Ville hors arrondissement (kreisfreie Stadt)
# 38                         Arrondissement (Landkreis)
# 39                         Arrondissement (Landkreis)
# 40                         Arrondissement (Landkreis)
# 41                         Arrondissement (Landkreis)
# 42                         Arrondissement (Landkreis)
# 43                         Arrondissement (Landkreis)
# 44       Ville hors arrondissement (kreisfreie Stadt)
# 45                         Arrondissement (Landkreis)
# 46                         Arrondissement (Landkreis)
# 47                         Arrondissement (Landkreis)
# 48                         Arrondissement (Landkreis)
# 49  Verviers - communes de la Communauté germanophone
# 50     Verviers - communes de la Communauté française
# 51                                     Arrondissement
# 52                                     Arrondissement
# 53                                     Arrondissement
# 54                                     Arrondissement
# 55                                        Grand-Duché
#
#                                             en_entity  population_2020  \
# 0                           District (arrondissement)           234103
# 1                           District (arrondissement)           151870
# 2                           District (arrondissement)            66892
# 3                           District (arrondissement)           364590
# 4                           District (arrondissement)            47990
# 5                           District (arrondissement)            38069
# 6                           District (arrondissement)            28774
# 7                           District (arrondissement)            33141
# 8                           District (arrondissement)            36512
# 9                           District (arrondissement)            36512
# 10                          District (arrondissement)            31061
# 11                          District (arrondissement)            64566
# 12                          District (arrondissement)           187130
# 13                          District (arrondissement)            38685
# 14      independent urban district (kreisfreie Stadt)            70290
# 15                               District (Landkreis)            74747
# 16                               District (Landkreis)            75544
# 17                               District (Landkreis)            91575
# 18                               District (Landkreis)            46457
# 19                               District (Landkreis)            35709
# 20                               District (Landkreis)           127060
# 21                               District (Landkreis)           105909
# 22                               District (Landkreis)            60226
# 23                               District (Landkreis)            71478
# 24                               District (Landkreis)           119754
# 25      independent urban district (kreisfreie Stadt)            73207
# 26                               District (Landkreis)            65845
# 27                               District (Landkreis)            59196
# 28                               District (Landkreis)            34938
# 29                               District (Landkreis)            89885
# 30      independent urban district (kreisfreie Stadt)            28359
# 31      independent urban district (kreisfreie Stadt)            62876
# 32      independent urban district (kreisfreie Stadt)           103856
# 33      independent urban district (kreisfreie Stadt)           142446
# 34      independent urban district (kreisfreie Stadt)            22881
# 35      independent urban district (kreisfreie Stadt)            30305
# 36      independent urban district (kreisfreie Stadt)            50367
# 37      independent urban district (kreisfreie Stadt)            20114
# 38                               District (Landkreis)            77941
# 39                               District (Landkreis)            77368
# 40                               District (Landkreis)            44233
# 41                               District (Landkreis)            78990
# 42                               District (Landkreis)            61914
# 43                               District (Landkreis)            41038
# 44      independent urban district (kreisfreie Stadt)            29298
# 45                               District (Landkreis)            65488
# 46                               District (Landkreis)            90753
# 47                               District (Landkreis)           126775
# 48                               District (Landkreis)            55345
# 49  Verviers - municipalities of the German community            45838
# 50  Verviers - municipalities of the French Community           121232
# 51                          District (arrondissement)            51539
# 52                          District (arrondissement)           249171
# 53                          District (arrondissement)           111749
# 54                          District (arrondissement)            88033
# 55                                        Grand Duchy           400597
#
#     population_2050  pop_projection_percentage description  \
# 0            245259                        4.8
# 1            145531                       -4.2
# 2             67229                        0.5
# 3            352595                       -3.3
# 4             54426                       13.4
# 5             38152                        0.2
# 6             32972                       14.6
# 7             28629                      -13.6
# 8             38646                        5.8
# 9             38646                        5.8
# 10            29178                       -6.1
# 11            65972                        2.2
# 12           189618                        1.3
# 13            32292                      -16.5
# 14            61307                      -12.8
# 15            60683                      -18.8
# 16            58957                      -22.0
# 17            74010                      -19.2
# 18            34261                      -26.3
# 19            27025                      -24.3
# 20           104573                      -17.7
# 21            85243                      -19.5
# 22            46007                      -23.6
# 23            57050                      -20.2
# 24            94812                      -20.8
# 25            64153                      -12.4
# 26            52438                      -20.4
# 27            49040                      -17.2
# 28            26378                      -24.5
# 29            77676                      -13.6
# 30            25603                       -9.7
# 31            54163                      -13.9
# 32            97270                       -6.3
# 33           129696                       -9.0
# 34            17268                      -24.5
# 35            25747                      -15.0
# 36            44412                      -11.8
# 37            16246                      -19.2
# 38            64196                      -17.6
# 39            63299                      -18.2
# 40            33772                      -23.6
# 41            66694                      -15.6
# 42            49239                      -20.5
# 43            30292                      -26.2
# 44            25075                      -14.4
# 45            54558                      -16.7
# 46            79255                      -12.7
# 47           108510                      -14.4
# 48            40524                      -26.8
# 49            41196                      -10.1
# 50           116945                       -3.5
# 51            55221                        7.1
# 52           227580                       -8.7
# 53           108945                       -2.5
# 54            86611                       -1.6
# 55           531808                       32.8
#
#                                              geometry
# 0   POLYGON ((4.75090 50.80705, 4.74888 50.80724, ...
# 1   POLYGON ((3.91197 50.61542, 3.91230 50.61647, ...
# 2   POLYGON ((5.29186 50.63330, 5.28140 50.63716, ...
# 3   POLYGON ((5.69315 50.81199, 5.69263 50.81205, ...
# 4   MULTIPOLYGON (((5.34921 50.63342, 5.34873 50.6...
# 5   POLYGON ((5.74202 49.85778, 5.73887 49.85690, ...
# 6   POLYGON ((5.88697 50.33965, 5.88331 50.34018, ...
# 7   POLYGON ((5.44110 50.42069, 5.43369 50.42410, ...
# 8   POLYGON ((5.06469 50.10367, 5.06135 50.10537, ...
# 9   POLYGON ((5.06469 50.10367, 5.06135 50.10537, ...
# 10  POLYGON ((5.41274 49.78665, 5.41282 49.78841, ...
# 11  POLYGON ((5.22126 50.41730, 5.21804 50.41551, ...
# 12  POLYGON ((4.96654 50.64812, 4.96476 50.64833, ...
# 13  POLYGON ((4.50460 50.32898, 4.49075 50.32868, ...
# 14  POLYGON ((7.68250 50.35527, 7.68231 50.35780, ...
# 15  POLYGON ((7.21087 50.64954, 7.20462 50.64865, ...
# 16  POLYGON ((7.80879 50.93880, 7.80719 50.93983, ...
# 17  POLYGON ((7.74180 49.99882, 7.73923 49.99981, ...
# 18  POLYGON ((7.37428 49.89953, 7.37372 49.89917, ...
# 19  POLYGON ((7.17382 50.28111, 7.17243 50.28135, ...
# 20  POLYGON ((7.35564 50.46545, 7.35506 50.46583, ...
# 21  MULTIPOLYGON (((7.70079 50.59982, 7.69928 50.5...
# 22  POLYGON ((7.61327 50.26063, 7.61242 50.26140, ...
# 23  POLYGON ((7.94479 50.39880, 7.94600 50.40067, ...
# 24  MULTIPOLYGON (((7.68034 50.56348, 7.68044 50.5...
# 25  POLYGON ((6.67148 49.84732, 6.67233 49.84428, ...
# 26  POLYGON ((6.86062 50.12938, 6.85861 50.13050, ...
# 27  POLYGON ((6.42529 50.32301, 6.42045 50.32334, ...
# 28  POLYGON ((6.60309 50.37624, 6.60120 50.37838, ...
# 29  POLYGON ((6.70512 49.90902, 6.70339 49.91015, ...
# 30  POLYGON ((8.37914 49.53598, 8.37924 49.53681, ...
# 31  POLYGON ((7.75837 49.39475, 7.75902 49.39471, ...
# 32  POLYGON ((8.38997 49.54568, 8.38857 49.54443, ...
# 33  POLYGON ((8.22844 49.92112, 8.23195 49.92130, ...
# 34  POLYGON ((7.66086 49.21602, 7.66133 49.21588, ...
# 35  POLYGON ((8.48051 49.28594, 8.48226 49.28654, ...
# 36  POLYGON ((8.37841 49.73142, 8.37757 49.72476, ...
# 37  POLYGON ((7.38516 49.21281, 7.38550 49.21285, ...
# 38  POLYGON ((8.17692 49.90001, 8.17412 49.89898, ...
# 39  POLYGON ((8.18328 49.62885, 8.17937 49.62766, ...
# 40  POLYGON ((7.86898 49.75656, 7.86795 49.75709, ...
# 41  POLYGON ((8.32720 49.29774, 8.32713 49.29772, ...
# 42  POLYGON ((7.74158 49.59036, 7.74200 49.59097, ...
# 43  POLYGON ((7.53620 49.71399, 7.53047 49.71004, ...
# 44  MULTIPOLYGON (((7.98779 49.17053, 7.98923 49.1...
# 45  POLYGON ((8.00172 49.33911, 8.00099 49.33942, ...
# 46  POLYGON ((8.35675 49.60743, 8.35548 49.60722, ...
# 47  POLYGON ((7.76660 50.08136, 7.76484 50.08259, ...
# 48  POLYGON ((7.60906 49.37297, 7.60780 49.37432, ...
# 49  MULTIPOLYGON (((6.20656 50.52085, 6.20629 50.5...
# 50  POLYGON ((5.96840 50.76080, 5.96175 50.76194, ...
# 51  POLYGON ((3.70908 50.77467, 3.70946 50.77585, ...
# 52  POLYGON ((4.24081 50.60027, 4.24102 50.60162, ...
# 53  POLYGON ((3.85845 50.75122, 3.85763 50.75163, ...
# 54  POLYGON ((4.25033 50.47454, 4.24989 50.47464, ...
# 55  POLYGON ((6.02490 50.18278, 6.02474 50.18274, ...

# %%
# general cleaning: renaming, and dropping duplicated region_y column
mergeddata.rename(columns={'region_x': 'region'}, inplace=True)

mergeddata = mergeddata.drop(['region_y'], axis=1)

# %%
mergeddata.head()
# Out:
#        city region  population_1999  population_2019 change_in_percentage  \
# 0  Nivelles    WAL           205678           233225                 13.4
# 1      Mons    WAL           146238           152166                  4.1
# 2       Huy    WAL            57971            66806                 15.2
# 3     Liège    WAL           346789           365136                  5.3
# 4   Waremme    WAL            39772            47761                 20.1
#
#    objectid               de_entity       fr_entity  \
# 0         2  Kreis (arrondissement)  Arrondissement
# 1         5  Kreis (arrondissement)  Arrondissement
# 2        10  Kreis (arrondissement)  Arrondissement
# 3        11  Kreis (arrondissement)  Arrondissement
# 4        12  Kreis (arrondissement)  Arrondissement
#
#                    en_entity  population_2020  population_2050  \
# 0  District (arrondissement)           234103           245259
# 1  District (arrondissement)           151870           145531
# 2  District (arrondissement)            66892            67229
# 3  District (arrondissement)           364590           352595
# 4  District (arrondissement)            47990            54426
#
#    pop_projection_percentage description  \
# 0                        4.8
# 1                       -4.2
# 2                        0.5
# 3                       -3.3
# 4                       13.4
#
#                                             geometry
# 0  POLYGON ((4.75090 50.80705, 4.74888 50.80724, ...
# 1  POLYGON ((3.91197 50.61542, 3.91230 50.61647, ...
# 2  POLYGON ((5.29186 50.63330, 5.28140 50.63716, ...
# 3  POLYGON ((5.69315 50.81199, 5.69263 50.81205, ...
# 4  MULTIPOLYGON (((5.34921 50.63342, 5.34873 50.6...

# %%
mergeddata.isna().sum()
# Out:
# city                         0
# region                       0
# population_1999              0
# population_2019              0
# change_in_percentage         0
# objectid                     0
# de_entity                    0
# fr_entity                    0
# en_entity                    0
# population_2020              0
# population_2050              0
# pop_projection_percentage    0
# description                  0
# geometry                     0
# dtype: int64

# %%
# importing the final clean mergeddata to make it easier to visualise it in Tableau

mergeddata.to_csv('/Users/szabonikolett/Downloads/mergeddata.csv')

# %%
#workchange.to_sql('MidProject', con, schema=None, if_exists='fail', index=True, index_label=None, chunksize=None, dtype=None, method=None)
# DataFrame.to_sql(name, con, schema=None, if_exists='fail', index=True, index_label=None, chunksize=None, dtype=None, method=None)

# %% [markdown]
# # SQL database import - export

# %%
# importing the final dataset to SQL Workbench

import pymysql
from sqlalchemy import create_engine

import getpass  # To get the password without showing the input
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/mid_project'
engine = create_engine(connection_string) # creates the connection to the database

mergeddata.to_sql('mergeddata', con=engine, index=False)

# %%
# get the data
connection_string = 'mysql+pymysql://root:' + password + '@localhost/mid_project'
engine = create_engine(connection_string) # creates the connection to the database
query = '''SELECT * FROM mergeddata;'''

data = pd.read_sql_query(query, engine)
data.head()
# Out:
#        city region  population_1999  population_2019 change_in_percentage  \
# 0  Nivelles    WAL           205678           233225                 13.4
# 1      Mons    WAL           146238           152166                  4.1
# 2       Huy    WAL            57971            66806                 15.2
# 3     Liège    WAL           346789           365136                  5.3
# 4   Waremme    WAL            39772            47761                 20.1
#
#    population_2020  population_2050  pop_projection_percentage
# 0           234103           245259                        4.8
# 1           151870           145531                       -4.2
# 2            66892            67229                        0.5
# 3           364590           352595                       -3.3
# 4            47990            54426                       13.4

# %% [markdown]
# ## Hypotheses test

# %%
workchange['population_1999'].mean()
# Out:
# 84964.18987341772

# %%
workchange['population_2019'].mean()
# Out:
# 87202.58227848102

# %%
projection['population_2020'].mean()
# Out:
# 108656.11111111111

# %% [markdown]
# Choosing two-tailed hypotheses test as in my testing I am trying to test in the alternative hypotheses if the population will either increase or decrease while the one-tailed test's alternative hypotheses would only test whether it changes or not.

# %% [markdown]
# First Hypothesis:
#
#     - Zero hypothesis: the mean population of 2020 equals to the mean population of 1999
#     - Alternative hypothesis: the mean population of 2020 does not equal to the mean population of 2020

# %%
# Two sided testing: 
# Null hypothesis: mean of population in 1999 = mean of poupulation of 2020
# Alternative hypothesis: mean population of 1999 will not equal to the mean population of 2020 

# H0 = 
# H1 != 

from scipy.stats import ttest_1samp

stat, pval = ttest_1samp(workchange['population_1999'], projection['population_2020'].mean())

# %%
print('Stat is  ', stat)
print('P value for the two-tailed test is ', pval)

# stat - : workchange 1999 is smaller than my base of comp. stat is for < >
# this is the one to KEEP
# reject null, by stat: pop 1999 is less
# Out:
# Stat is   -3.1230767211916812
# P value for the two-tailed test is  0.0025115773581651526

# %% [markdown]
# Rejecting the Null hypothesis, P value is very low. The high variance between the values resulted in the negative T value, the alternative hypothesis can be accepted, the mean working age population was less in 1999, proving it increased by 2020.

# %%
# Trying one sided test
# Null hypothesis: The population in 2020 will be significantly less =< the population in 1999
# Alternative hypothesis: The population in 2020 will be significantly greater > the population in 1999
# alternative: 2020 population will not be significantly greater than 1999

from scipy.stats import ttest_1samp

stat, pval = ttest_1samp(projection['population_2020'], workchange['population_1999'].mean())

# %%
print('Stat is  ', stat)

print('Pvalue for the one-tailed test is ', pval/2)
# Out:
# Stat is   1.5574228009054683
# Pvalue for the one-tailed test is  0.06223021212274814

# %%
# p value is the evidence against a null hypothesis. The smaller the p-value, the stronger the evidence that the null hypothesis can be reject3ed.
